# %%
import  matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# Out:
# C:\Users\admin\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_excel('data.xls') # 导入Excel文件
# 多折线图
x = df1['姓名']
y1 = df1['语文']
y2 = df1['数学']
y3 = df1['英语']

plt.rcParams['font.sans-serif'] = ['SimHei'] #解决中文乱码
plt.rcParams['xtick.direction'] = 'out' #刻度线向外
plt.rcParams['ytick.direction'] = 'in' #刻度线向内
plt.title('语数外成绩大比拼',fontsize=14)
plt.plot(x,y1,label='语文',color='r',marker='v')
plt.plot(x,y2,label='数学',color='g',marker='.',mfc='r',ms=8,alpha=0.7)
plt.plot(x,y3,label='英语',color='b',linestyle='-.',marker='*')
plt.grid(axis='y') #显示网格关闭y轴
plt.ylabel='成绩'
plt.yticks(range(50,150,10))
plt.legend(['语文','数学','英语'])

# %% [markdown]
# 最常用的魔法命令，大概就是 %matplotlib了。它用于指定 matplotlib 的后端(backend)。通常我们使用：
#
# %matplotlib inline
#
# 代表使用 inline作为后端，直接在 Notebook 中内嵌图片，并且可以省略掉 plt.show() 这一步骤。

# %% [markdown]
# ## 小技巧1：如何使用map对某些列做特征工程？

# %%
import  pandas as pd
data = {'gender':['female','male','female','male'],
       'color':['red','green','blue','green'],
       'age':[25,30,15,32]}
df = pd.DataFrame(data)
df
# Out:
#    gender  color  age
# 0  female    red   25
# 1    male  green   30
# 2  female   blue   15
# 3    male  green   32

# %%
d = {'female':'女','male':'男'}  # 在 gender 列上，使用 map 方法，快速完成如下映射：
df['xingbie'] = df['gender'].map(d)
df
# Out:
#    gender  color  age xingbie
# 0  female    red   25       女
# 1    male  green   30       男
# 2  female   blue   15       女
# 3    male  green   32       男

# %% [markdown]
# ## 小技巧2：使用 replace 和正则清洗数据

# %%
d = {"customer": ["A", "B", "C", "D"],
     "sales":[1100, "950.5RMB", "$400", " $1250.75"]}

df = pd.DataFrame(d)
df
# Out:
#   customer      sales
# 0        A       1100
# 1        B   950.5RMB
# 2        C       $400
# 3        D   $1250.75

# %% [markdown]
# ales 列的值，有整型，浮点型+RMB后变为字符串型，还有美元+整型，美元+浮点型。
#
# 我们的目标：清洗掉 RMB，$ 符号，转化这一列为浮点型。

# %%
df["sales"] = df["sales"].replace("[$,RMB]","", regex = True).astype("float")
df
# Out:
#   customer    sales
# 0        A  1100.00
# 1        B   950.50
# 2        C   400.00
# 3        D  1250.75

# %% [markdown]
# 使用正则替换，将要替换的字符放到列表中 [$,RMB]，替换为空字符，即 ""；
#
# 最后使用 astype 转为 float

# %% [markdown]
# ## 小技巧3：如何重新排序 DataFrame 的列？
#
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202021-02-04%20221518.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202021-02-04%20221518.png)

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0,20,size=(5,7)) ,columns=list('ABCDEFG'))
df
# Out:
#     A   B   C   D   E   F   G
# 0  14   1   8  17   3  10  11
# 1  11   6  19  13  11  18  13
# 2  12  13  12  15   4  17   7
# 3   0   0   5   8   6  15   3
# 4   0   7  17   1   7  11  10

# %%
# 第一种方法：使用标签索引
df2 = df[['A','C','D','F','E','G','B']]
df2
# Out:
#     A   C   D   F   E   G   B
# 0  14   8  17  10   3  11   1
# 1  11  19  13  18  11  13   6
# 2  12  12  15  17   4   7  13
# 3   0   5   8  15   6   3   0
# 4   0  17   1  11   7  10   7
